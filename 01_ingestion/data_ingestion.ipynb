# %%
# %sql
-- Create the initial catalog
CREATE CATALOG retail_catalog;

# %%
# %sql
-- Create bronze schema for storing raw data
CREATE SCHEMA retail_catalog.bronze;

# %%
# %sql
-- Create silver schema for storing cleaned and validated data 
CREATE SCHEMA IF NOT EXISTS retail_catalog.silver;

# %%
# %sql
-- Create gold schema for storing tables for analysis and dashboard preperation
CREATE SCHEMA IF NOT EXISTS retail_catalog.gold;

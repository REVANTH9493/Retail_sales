# %%
# %sql
SELECT COUNT(*) AS source_count
FROM retail_catalog.bronze.customers_raw;

# %%
# %sql
SELECT COUNT(*) AS target_count
FROM retail_catalog.silver.dim_customer
WHERE IsActive = 1;

# %%
# %sql
SELECT COUNT(*) FROM retail_catalog.bronze.products_raw;

# %%
# %sql
SELECT COUNT(*) FROM retail_catalog.silver.dim_product;

# %%
# %sql
SELECT COUNT(*) FROM retail_catalog.bronze.stores_raw;

# %%
# %sql
SELECT COUNT(*) FROM retail_catalog.silver.dim_store;

# %%
# %sql
SELECT COUNT(*) FROM retail_catalog.bronze.sales_raw;

# %%
# %sql
SELECT COUNT(*) FROM retail_catalog.silver.fact_sales;

# %%
# %sql
SELECT
    b.CustomerID AS source_customerid,
    s.CustomerID AS target_customerid
FROM retail_catalog.bronze.customers_raw b
JOIN retail_catalog.silver.dim_customer s
    ON b.CustomerID = s.CustomerID
WHERE s.IsActive = 1;

# %%
# %sql
SELECT
    b.ProductID,
    s.ProductID
FROM retail_catalog.bronze.products_raw b
JOIN retail_catalog.silver.dim_product s
    ON b.ProductID = s.ProductID;

# %%
# %sql
SELECT
    b.StoreID,
    s.StoreID
FROM retail_catalog.bronze.stores_raw b
JOIN retail_catalog.silver.dim_store s
    ON b.StoreID = s.StoreID;

# %%
# %sql
SELECT
    b.TransactionID,
    s.TransactionID
FROM retail_catalog.bronze.sales_raw b
JOIN retail_catalog.silver.fact_sales s
    ON b.TransactionID = s.TransactionID;

# %%
# %sql
DESC retail_catalog.silver.dim_customer;

# %%
# %sql
DESCRIBE retail_catalog.silver.fact_sales;

# %%
# %sql
DELETE FROM retail_catalog.bronze.customers_raw
WHERE CustomerID IS NULL;

# %%
# %sql
SELECT b.CustomerID
FROM retail_catalog.bronze.customers_raw b

LEFT JOIN retail_catalog.silver.dim_customer s
ON b.CustomerID = s.CustomerID
AND s.IsActive = 1

WHERE s.CustomerID IS NULL;

# %%
# %sql
DELETE FROM retail_catalog.silver.dim_customer
WHERE CustomerID IS NULL;

# %%
# %sql
SELECT b.TransactionID
FROM retail_catalog.bronze.sales_raw b

LEFT JOIN retail_catalog.silver.fact_sales s
ON b.TransactionID = s.TransactionID

WHERE s.TransactionID IS NULL;

# %%
# %sql
SELECT
    CustomerID,
    COUNT(*) AS active_count
FROM retail_catalog.silver.dim_customer
WHERE IsActive = 1
GROUP BY CustomerID
HAVING COUNT(*) > 1;

# %%
# %sql
SELECT
    ProductID,
    COUNT(*) AS duplicate_count
FROM retail_catalog.silver.dim_product
GROUP BY ProductID
HAVING COUNT(*) > 1;

# %%
# %sql
SELECT
    StoreID,
    COUNT(*) AS duplicate_count
FROM retail_catalog.silver.dim_store
GROUP BY StoreID
HAVING COUNT(*) > 1;

# %%
# %sql
SELECT
    TransactionID,
    COUNT(*) AS duplicate_count
FROM retail_catalog.silver.fact_sales
GROUP BY TransactionID
HAVING COUNT(*) > 1;

# %%
# %sql
SELECT *
FROM retail_catalog.silver.fact_sales
WHERE Quantity < 0;

# %%
# %sql
SELECT *
FROM retail_catalog.silver.fact_sales
WHERE Amount < 0;

# %%
# %sql
SELECT
    CustomerID,
    COUNT(*) AS active_records
FROM retail_catalog.silver.dim_customer
WHERE IsActive = 1
GROUP BY CustomerID
HAVING COUNT(*) > 1;

# %%
# %sql
SELECT *
FROM retail_catalog.silver.dim_customer
WHERE IsActive = 1
AND EndDate != DATE('9999-12-31');

# %%
# %sql
SELECT *
FROM retail_catalog.silver.dim_customer
WHERE IsActive = 0
AND EndDate = DATE('9999-12-31');
